# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\Dhaneshwari\Downloads\workout_fitness_tracker_data.csv")

# %%
df
# Out:
#      User ID  Age  Gender  Height (cm)  Weight (kg) Workout Type  \
# 0          1   39    Male          175           99      Cycling
# 1          2   36   Other          157          112       Cardio
# 2          3   25  Female          180           66         HIIT
# 3          4   56    Male          154           89      Cycling
# 4          5   53   Other          194           59     Strength
# ..       ...  ...     ...          ...          ...          ...
# 593      594   34  Female          156           73       Cardio
# 594      595   24    Male          172          104       Cardio
# 595      596   18  Female          168          113         HIIT
# 596      597   46  Female          157           54       Cardio
# 597      598   32    Male          172           72         Yoga
#
#      Workout Duration (mins)  Calories Burned  Heart Rate (bpm)  Steps Taken  \
# 0                         79              384               112         8850
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 598 entries, 0 to 597
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   User ID                   598 non-null    int64
#  1   Age                       598 non-null    int64
#  2   Gender                    598 non-null    object
#  3   Height (cm)               598 non-null    int64
#  4   Weight (kg)               598 non-null    int64
#  5   Workout Type              598 non-null    object
#  6   Workout Duration (mins)   598 non-null    int64
#  7   Calories Burned           598 non-null    int64
#  8   Heart Rate (bpm)          598 non-null    int64
#  9   Steps Taken               598 non-null    int64
#  10  Distance (km)             598 non-null    float64
#  11  Workout Intensity         598 non-null    object
#  12  Sleep Hours               598 non-null    float64
#  13  Water Intake (liters)     598 non-null    float64
# ...

# %%
df.describe()
# Out:
#           User ID         Age  Height (cm)  Weight (kg)  \
# count  598.000000  598.000000   598.000000   598.000000
# mean   299.500000   39.015050   174.745819    83.618729
# std    172.772008   12.402441    13.936285    20.091794
# min      1.000000   18.000000   150.000000    50.000000
# 25%    150.250000   28.000000   163.000000    65.250000
# 50%    299.500000   39.000000   174.000000    84.500000
# 75%    448.750000   50.000000   187.000000   100.000000
# max    598.000000   59.000000   199.000000   119.000000
#
#        Workout Duration (mins)  Calories Burned  Heart Rate (bpm)  \
# count               598.000000       598.000000        598.000000
# mean                 64.993311       547.678930        129.717391
# std                  31.855304       246.549801         28.683779
# min                  10.000000       101.000000         80.000000
# 25%                  37.000000       352.250000        106.000000
# ...

# %%
df.head()
# Out:
#    User ID  Age  Gender  Height (cm)  Weight (kg) Workout Type  \
# 0        1   39    Male          175           99      Cycling
# 1        2   36   Other          157          112       Cardio
# 2        3   25  Female          180           66         HIIT
# 3        4   56    Male          154           89      Cycling
# 4        5   53   Other          194           59     Strength
#
#    Workout Duration (mins)  Calories Burned  Heart Rate (bpm)  Steps Taken  \
# 0                       79              384               112         8850
# 1                       73              612               168         2821
# 2                       27              540               133        18898
# 3                       39              672               118        14102
# 4                       56              410               170        16518
#
#    Distance (km) Workout Intensity  Sleep Hours  Water Intake (liters)  \
# ...

# %%
df.columns
# Out:
# Index(['User ID', 'Age', 'Gender', 'Height (cm)', 'Weight (kg)',
#        'Workout Type', 'Workout Duration (mins)', 'Calories Burned',
#        'Heart Rate (bpm)', 'Steps Taken', 'Distance (km)', 'Workout Intensity',
#        'Sleep Hours', 'Water Intake (liters)', 'Daily Calories Intake',
#        'Resting Heart Rate (bpm)', 'VO2 Max', 'Body Fat (%)',
#        'Mood Before Workout', 'Mood After Workout'],
#       dtype='object')

# %%
plt.figure(figsize=(5,5))
plt.scatter(df['Workout Type'],df['Workout Duration (mins)'])
plt.xlabel("Workout Type")
plt.ylabel("Workout Duration (mins)")
# Out:
# Text(0, 0.5, 'Workout Duration (mins)')

# %%
plt.figure(figsize=(5,5))
plt.bar(df['Workout Type'],df['Calories Burned'])
plt.xlabel("Workout Type")
plt.ylabel("Calories Burned")
# Out:
# Text(0, 0.5, 'Calories Burned')

# %%
plt.figure(figsize=(5,5))
plt.scatter(df['Steps Taken'],df['Distance (km)'])
plt.xlabel("Steps Taken")
plt.ylabel("Distance (km)")
# Out:
# Text(0, 0.5, 'Distance (km)')

# %%
plt.figure(figsize=(5,5))
plt.scatter(df['Mood Before Workout'],df['Mood After Workout'])
plt.xlabel("Mood before Workout")
plt.ylabel("Mood After Workout")
# Out:
# Text(0, 0.5, 'Mood After Workout')

# %%
df.hist(figsize=(10,10), bins=30)
plt.show()


plt.figure(figsize=(10,10))
sns.boxplot(data=df)
plt.xticks(rotation=90)
plt.show()
for col in df.select_dtypes(include=['object']).columns:
    plt.figure(figsize=(8, 4))
    sns.countplot(y=df[col], order=df[col].value_counts().index)
    plt.title(col)
    plt.show()

# %%
def bar_plot(var):
    v=df[var]
    varValue=v.value_counts()
    plt.figure(figsize=(4,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("frequency")
    plt.title(var)
    plt.show()
    print("{}: \n {} ".format(var,varValue))

# %%
df.columns
# Out:
# Index(['User ID', 'Age', 'Gender', 'Height (cm)', 'Weight (kg)',
#        'Workout Type', 'Workout Duration (mins)', 'Calories Burned',
#        'Heart Rate (bpm)', 'Steps Taken', 'Distance (km)', 'Workout Intensity',
#        'Sleep Hours', 'Water Intake (liters)', 'Daily Calories Intake',
#        'Resting Heart Rate (bpm)', 'VO2 Max', 'Body Fat (%)',
#        'Mood Before Workout', 'Mood After Workout'],
#       dtype='object')

# %%
column_data=[ 'Age', 'Gender', 'Height (cm)', 'Weight (kg)','Workout Type', 'Workout Duration (mins)', 'Calories Burned']
for i in column_data:
    bar_plot(i)
# Out:
# Age:
#  Age
# 56    21
# 51    21
# 34    20
# 38    19
# 40    19
# 21    18
# 44    17
# 19    17
# 29    17
# 41    17
# 59    17
# 52    17
# 23    17
# 20    17
# 54    16
# 57    16
# 58    16
# 47    15
# 39    15
# 28    15
# 45    14
# 32    14
# 24    13
# 48    13
# 36    13
# 46    13
# 31    13
# 55    13
# 43    12
# 18    12
# 25    12
# 26    12
# 53    12
# 37    12
# 49    11
# 27    11
# 22    10
# 33    10
# 42     9
# 35     9
# 50     8
# 30     5
# Name: count, dtype: int64
# Gender:
#  Gender
# Female    214
# Male      207
# Other     177
# Name: count, dtype: int64
# Height (cm):
#  Height (cm)
# 157    19
# 170    18
# 188    17
# 172    16
# 167    16
# 174    16
# 190    16
# 187    15
# 189    15
# 160    15
# 168    15
# 161    15
# 185    15
# 178    13
# 171    13
# 176    13
# 181    13
# 192    13
# 180    13
# 164    13
# 182    13
# 166    13
# 165    13
# 183    12
# 195    12
# 156    12
# 199    12
# 191    12
# 152    12
# 155    12
# ...

# %%
plt.hist(df['Workout Duration (mins)'])
plt.show()

# %%
df[['Age','Workout Type']].groupby(['Age'],as_index=False).count().sort_values(by='Workout Type',ascending=False)
# Out:
#     Age  Workout Type
# 33   51            21
# 38   56            21
# 16   34            20
# 22   40            19
# 20   38            19
# 3    21            18
# 41   59            17
# 23   41            17
# 26   44            17
# 11   29            17
# 34   52            17
# 5    23            17
# 2    20            17
# 1    19            17
# 36   54            16
# 39   57            16
# 40   58            16
# 29   47            15
# 21   39            15
# 10   28            15
# 14   32            14
# 27   45            14
# 30   48            13
# 6    24            13
# 37   55            13
# 13   31            13
# 28   46            13
# 18   36            13
# 7    25            12
# 8    26            12
# 35   53            12
# 19   37            12
# 25   43            12
# 0    18            12
# 31   49            11
# 9    27            11
# 15   33            10
# 4    22            10
# 24   42             9
# 17   35             9
# ...

# %%
df[['Workout Type', 'Workout Duration (mins)']].groupby(['Workout Type'],as_index=False).mean().sort_values(by='Workout Duration (mins)',ascending=False)
# Out:
#   Workout Type  Workout Duration (mins)
# 2         HIIT                67.336538
# 4     Strength                66.354839
# 5         Yoga                66.108108
# 0       Cardio                66.091837
# 3      Running                64.902174
# 1      Cycling                59.060000

# %%
df[['Gender','Sleep Hours']].groupby(['Gender'],as_index=False).mean().sort_values(by='Sleep Hours',ascending=False)
# Out:
#    Gender  Sleep Hours
# 0  Female     6.829907
# 2   Other     6.734463
# 1    Male     6.724638

# %%
df.isna().sum()
# Out:
# User ID                     0
# Age                         0
# Gender                      0
# Height (cm)                 0
# Weight (kg)                 0
# Workout Type                0
# Workout Duration (mins)     0
# Calories Burned             0
# Heart Rate (bpm)            0
# Steps Taken                 0
# Distance (km)               0
# Workout Intensity           0
# Sleep Hours                 0
# Water Intake (liters)       0
# Daily Calories Intake       0
# Resting Heart Rate (bpm)    0
# VO2 Max                     0
# Body Fat (%)                0
# Mood Before Workout         0
# Mood After Workout          0
# dtype: int64

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.violinplot(df['Workout Duration (mins)'])
# Out:
# <Axes: ylabel='Workout Duration (mins)'>

# %%
sns.catplot(df['Gender'])

# %%
sns.pointplot(df['Steps Taken'])
# Out:
# <Axes: ylabel='Steps Taken'>

# %%
df.columns
# Out:
# Index(['User ID', 'Age', 'Gender', 'Height (cm)', 'Weight (kg)',
#        'Workout Type', 'Workout Duration (mins)', 'Calories Burned',
#        'Heart Rate (bpm)', 'Steps Taken', 'Distance (km)', 'Workout Intensity',
#        'Sleep Hours', 'Water Intake (liters)', 'Daily Calories Intake',
#        'Resting Heart Rate (bpm)', 'VO2 Max', 'Body Fat (%)',
#        'Mood Before Workout', 'Mood After Workout'],
#       dtype='object')

# %%
df.drop(labels=['User ID', 'Heart Rate (bpm)', 'Workout Intensity', 'Water Intake (liters)', 'Daily Calories Intake',
       'Resting Heart Rate (bpm)', 'VO2 Max', 'Body Fat (%)',
       'Mood Before Workout', 'Mood After Workout'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Height (cm)', 'Weight (kg)', 'Workout Type',
#        'Workout Duration (mins)', 'Calories Burned', 'Steps Taken',
#        'Distance (km)', 'Sleep Hours'],
#       dtype='object')

# %%
df.head()
# Out:
#    Age  Gender  Height (cm)  Weight (kg) Workout Type  \
# 0   39    Male          175           99      Cycling
# 1   36   Other          157          112       Cardio
# 2   25  Female          180           66         HIIT
# 3   56    Male          154           89      Cycling
# 4   53   Other          194           59     Strength
#
#    Workout Duration (mins)  Calories Burned  Steps Taken  Distance (km)  \
# 0                       79              384         8850          14.44
# 1                       73              612         2821           1.10
# 2                       27              540        18898           7.28
# 3                       39              672        14102           6.55
# 4                       56              410        16518           3.17
#
#    Sleep Hours
# 0          8.2
# 1          8.6
# 2          9.8
# 3          5.8
# 4          7.3

# %%
df['Gender'] = df['Gender'].astype(str)

# %%
df = pd.get_dummies(df, columns=['Gender'], drop_first=True)

# %%
df.head()
# Out:
#    Age  Height (cm)  Weight (kg) Workout Type  Workout Duration (mins)  \
# 0   39          175           99      Cycling                       79
# 1   36          157          112       Cardio                       73
# 2   25          180           66         HIIT                       27
# 3   56          154           89      Cycling                       39
# 4   53          194           59     Strength                       56
#
#    Calories Burned  Steps Taken  Distance (km)  Sleep Hours  Gender_Male  \
# 0              384         8850          14.44          8.2         True
# 1              612         2821           1.10          8.6        False
# 2              540        18898           7.28          9.8        False
# 3              672        14102           6.55          5.8         True
# 4              410        16518           3.17          7.3        False
#
#    Gender_Other
# 0         False
# 1          True
# 2         False
# 3         False
# ...

# %%
#numeric_df = df.select_dtypes(include=['number'])
plt.figure(figsize=(7,6)) 
sns.heatmap(numeric_df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.show()
